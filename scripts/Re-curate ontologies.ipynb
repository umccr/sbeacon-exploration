# %% [markdown]
# The CINECA data has ICD codes for diseases rather than a proper ontology. As we are interested in ontology expansion when querying, I want to replace these with ontology terms from ontologies such as MONDO and/or HP which have a hierarchy and allow for ontology expansion from more general terms.
#
# The ethnicity ontologies are also somewhat problematic as they are quite generalised and the labels are not consistent with the ontology curie given. I will also attempt to recurate these.
#
# These terms are in the individuals sheet
#
# I will use the EBI OLS API and maybe the ZOOMA one too.
#
# https://www.ebi.ac.uk/ols/docs/api

# %%
import requests as rq
import pandas as pd
import json
import numpy as np
import openpyxl as op
from requests.structures import CaseInsensitiveDict
import pprint
from collections import OrderedDict

# %% [markdown]
# Load workbook, make individuals dataframe

# %%
excel_ss = op.load_workbook("/Users/marionfs/Documents/GitHub/sbeacon-exploration/data/CINECA_synthetic_cohort_EUROPE_UK1/Beacon-v2-Models_CINECA_UK1.xlsx", read_only=True)
ind_df = pd.DataFrame(excel_ss['individuals'].values)
ind_df_columns = ind_df.values[:1]
ind_df.set_axis(list(ind_df_columns), axis=1, inplace=True)
ind_df.drop(index=ind_df.index[0], axis=0, inplace=True)
# Out:
# /Users/marionfs/jupyter-venv/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# /var/folders/n_/nhsj5dfn2bz8k043p90mb1c80000gp/T/ipykernel_54783/4161091586.py:4: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   ind_df.set_axis(list(ind_df_columns), axis=1, inplace=True)

# %%
ind_df
# Out:
#      ﻿diseases_ageOfOnset diseases_diseaseCode.id  \
# 1                    None                    None
# 2                    None                    None
# 3                    None                    None
# 4                    None                    None
# 5                    None                    None
# ...                   ...                     ...
# 2500                 None     ICD10:D70,ICD10:E06
# 2501                 None     ICD10:D86,ICD10:K74
# 2502                 None                    None
# 2503                 None     ICD10:E06,ICD10:K21
# 2504                 None               ICD10:K74
#
#                          diseases_diseaseCode.label diseases_familyHistory  \
# 1                                              None                   None
# 2                                              None                   None
# 3                                              None                   None
# 4                                              None                   None
# 5                                              None                   None
# ...                                             ...                    ...
# 2500                    agranulocytosis,thyroiditis                   None
# 2501    sarcoidosis,fibrosis and cirrhosis of liver                   None
# 2502                                           None                   None
# 2503  thyroiditis,gastro-oesophageal reflux disease                   None
# 2504                fibrosis and cirrhosis of liver                   None
#
#      diseases_notes diseases_severity.id diseases_severity.label  \
# 1              None                 None                    None
# 2              None                 None                    None
# 3              None                 None                    None
# 4              None                 None                    None
# 5              None                 None                    None
# ...             ...                  ...                     ...
# 2500           None                 None                    None
# 2501           None                 None                    None
# 2502           None                 None                    None
# 2503           None                 None                    None
# 2504           None                 None                    None
#
#      diseases_stage.id diseases_stage.label ethnicity.id  ...  \
# 1                 None                 None  NCIT:C42331  ...
# 2                 None                 None  NCIT:C41261  ...
# 3                 None                 None  NCIT:C41260  ...
# 4                 None                 None  NCIT:C67109  ...
# 5                 None                 None  NCIT:C67109  ...
# ...                ...                  ...          ...  ...
# 2500              None                 None  NCIT:C43856  ...
# 2501              None                 None  NCIT:C67109  ...
# 2502              None                 None  NCIT:C67109  ...
# 2503              None                 None         None  ...
# 2504              None                 None  NCIT:C41260  ...
#
#      treatments_cumulativeDose.referenceRange.low  \
# 1                                            None
# 2                                            None
# 3                                            None
# 4                                            None
# 5                                            None
# ...                                           ...
# 2500                                         None
# 2501                                         None
# 2502                                         None
# 2503                                         None
# 2504                                         None
#
#      treatments_cumulativeDose.referenceRange.unit  \
# 1                                             None
# 2                                             None
# 3                                             None
# 4                                             None
# 5                                             None
# ...                                            ...
# 2500                                          None
# 2501                                          None
# 2502                                          None
# 2503                                          None
# 2504                                          None
#
#      treatments_cumulativeDose.unit.id treatments_cumulativeDose.unit.label  \
# 1                                 None                                 None
# 2                                 None                                 None
# 3                                 None                                 None
# 4                                 None                                 None
# 5                                 None                                 None
# ...                                ...                                  ...
# 2500                              None                                 None
# 2501                              None                                 None
# 2502                              None                                 None
# 2503                              None                                 None
# 2504                              None                                 None
#
#      treatments_cumulativeDose.value treatments_doseIntervals  \
# 1                               None                     None
# 2                               None                     None
# 3                               None                     None
# 4                               None                     None
# 5                               None                     None
# ...                              ...                      ...
# 2500                            None                     None
# 2501                            None                     None
# 2502                            None                     None
# 2503                            None                     None
# 2504                            None                     None
#
#      treatments_routeOfAdministration.id  \
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None
# 5                                   None
# ...                                  ...
# 2500                                None
# 2501                                None
# 2502                                None
# 2503                                None
# 2504                                None
#
#      treatments_routeOfAdministration.label treatments_treatmentCode.id  \
# 1                                      None                        None
# 2                                      None                        None
# 3                                      None                        None
# 4                                      None                        None
# 5                                      None                        None
# ...                                     ...                         ...
# 2500                                   None                        None
# 2501                                   None                        None
# 2502                                   None                        None
# 2503                                   None                        None
# 2504                                   None                        None
#
#      treatments_treatmentCode.label
# 1                              None
# 2                              None
# 3                              None
# 4                              None
# 5                              None
# ...                             ...
# 2500                           None
# 2501                           None
# 2502                           None
# 2503                           None
# 2504                           None
#
# [2504 rows x 82 columns]

# %% [markdown]
# ## Change disease codes to mondo
# use mondo ontology for hierarchical structure for more intuitive searching.
#
# First, Get list of all unique disease labels

# %%
label_list = ind_df['diseases_diseaseCode.label'].values.tolist()

label_list = [item for sublist in label_list for item in sublist]
non_none = list(filter(lambda item: item is not None, label_list))

non_none = [item.split(',') for item in non_none]

non_none_flat = [item for sublist in non_none for item in sublist]

distinct_diseases = set(non_none_flat)

# %%
distinct_diseases
# Out:
# {'acute bronchitis',
#  'agranulocytosis',
#  'asthma',
#  'bipolar affective disorder',
#  'cardiomyopathy',
#  'dental caries',
#  'eating disorders',
#  'fibrosis and cirrhosis of liver',
#  'gastro-oesophageal reflux disease',
#  'haemorrhoids',
#  'influenza due to certain identified influenza virus',
#  'insulin-dependent diabetes mellitus',
#  'iron deficiency anaemia',
#  'multiple sclerosis',
#  'obesity',
#  'sarcoidosis',
#  'schizophrenia',
#  'thyroiditis',
#  'varicose veins of lower extremities'}

# %% [markdown]
# query EBI OLS MONDO for matches for each

# %%
# did not end up using Zooma, found OLS was better
# def zooma_lookup(ontology, query_term):
#    base_url = f"http://www.ebi.ac.uk/spot/zooma/v2/api/services/annotate?propertyValue={query_term}&required:[none]&ontologies:[mondo]"
#    headers = CaseInsensitiveDict()
#    headers['Accept'] = "application/json"
#    response = rq.get(base_url)
#    pprint.pprint(json.loads(response.content))

# %%
def ontology_lookup(ontology: str, query_term: str):
    """ Ontology Lookup
    
    ontology: The name of the ontology, e.g. mondo
    query_term: the string to lookup in that ontology
    
    Return: {'obo_id': ontology_curie, 
            'label': ontology_label}
    
    Method that helps curate an ontology term in a semi-automated way.
    It first searches the EBI OLS in the specified ontology for the query_term
    and presents numbered options for the user to choose from.
    If a suitable term is not found the user can enter 'n' and provide an 
    alternate query term.
    If still no term is found entering 'n' will provide a null value.
    Returns a dict with the curie in 'obo_id' and the label in 'label'
    """
    base_url = f"http://www.ebi.ac.uk/ols/api/search?q={query_term}&ontology={ontology.lower()}&queryFields=label,synonym"
    headers = CaseInsensitiveDict()
    headers['Accept'] = "application/json"
    response = rq.get(base_url, headers=headers)
    content = json.loads(response.content)
    total_terms_found = len(content['response']['docs'])
    if total_terms_found < 5:
        to_display = total_terms_found
    else:
        to_display = 5
    start=0
    # Check for exact matches first, must be MONDO and must be exact text match
    
    print("Choose the most appropriate ontology below, if none suitable enter n")
    for i in range(start, start+to_display, 1):
        print(f"{i+1}.{content['response']['docs'][i]['obo_id']} {content['response']['docs'][i]['label']}")
    chosen_term = input("Enter the number of the chosen ontology curation: ")
    if chosen_term.lower() == "n":
        new_term = input("If you would like to try to search a different term, enter it now, if not enter n")
        if new_term == "n":
            return None
        else:
            base_url = f"http://www.ebi.ac.uk/ols/api/search?q={new_term}&ontology={ontology.lower()}&queryFields=label,synonym" 
            response = rq.get(base_url, headers=headers)
            content = json.loads(response.content)
            total_terms_found = len(content['response']['docs'])
            if total_terms_found < 5:
                to_display = total_terms_found
            else:
                to_display = 5
            start=0
            print("Choose the most appropriate ontology below, if none suitable enter n")
            for i in range(start, start+to_display, 1):
                print(f"{i+1}.{content['response']['docs'][i]['obo_id']} {content['response']['docs'][i]['label']}")
            chosen_term = input("Enter the number of the chosen ontology curation: ")
            if chosen_term == "n":
                return None
            else:
                return {"obo_id": content['response']['docs'][int(chosen_term) - 1]['obo_id'], 
                        "label": content['response']['docs'][int(chosen_term) - 1]['label']}
    else:
        return {"obo_id": content['response']['docs'][int(chosen_term) - 1]['obo_id'], 
                "label": content['response']['docs'][int(chosen_term) - 1]['label']}

# %% [markdown]
# Iterate over diseases to get a dict of disease curations from mondo.

# %%
curation_dict = {}
for disease in distinct_diseases:
    print(f"The disease you are curating is: {disease}")
    curation = ontology_lookup("mondo", disease)
    curation_dict[disease] = curation
# Out:
# The disease you are curating is: obesity
# Choose the most appropriate ontology below, if none suitable enter n
# 1.HP:0001513 Obesity
# 2.MONDO:0019182 inherited obesity
# 3.MONDO:0005139 morbid obesity
# 4.MONDO:0011122 obesity disorder
# 5.MONDO:0009763 obesity-hypoventilation syndrome
# Enter the number of the chosen ontology curation: 4
# The disease you are curating is: cardiomyopathy
# Choose the most appropriate ontology below, if none suitable enter n
# 1.HP:0001638 Cardiomyopathy
# 2.MONDO:0004994 cardiomyopathy
# 3.MONDO:0010771 histiocytoid cardiomyopathy
# 4.MONDO:0030701 autoimmune cardiomyopathy
# 5.MONDO:0002824 extrinsic cardiomyopathy
# Enter the number of the chosen ontology curation: 2
# The disease you are curating is: sarcoidosis
# Choose the most appropriate ontology below, if none suitable enter n
# 1.MONDO:0019338 sarcoidosis
# 2.MONDO:0006611 skin sarcoidosis
# 3.MONDO:0001709 hypercalcemic sarcoidosis
# 4.MONDO:0001708 pulmonary sarcoidosis
# 5.MONDO:0001707 cardiac sarcoidosis
# Enter the number of the chosen ontology curation: 1
# The disease you are curating is: haemorrhoids
# Choose the most appropriate ontology below, if none suitable enter n
# Enter the number of the chosen ontology curation: n
# If you would like to try to search a different term, enter it now, if not enter nn
# The disease you are curating is: thyroiditis
# Choose the most appropriate ontology below, if none suitable enter n
# 1.MONDO:0004126 thyroiditis
# 2.MONDO:0006982 subacute thyroiditis
# 3.MONDO:0005624 atrophic thyroiditis
# 4.MONDO:0044014 postpartum thyroiditis
# 5.MONDO:0007699 Hashimoto thyroiditis
# Enter the number of the chosen ontology curation: 1
# The disease you are curating is: bipolar affective disorder
# Choose the most appropriate ontology below, if none suitable enter n
# 1.MONDO:0024612 manic bipolar affective disorder
# 2.MONDO:0012319 major affective disorder 3
# 3.MONDO:0007440 major affective disorder 1
# 4.MONDO:0000694 seasonal affective disorder
# 5.MONDO:0012685 major affective disorder 5
# Enter the number of the chosen ontology curation: 1
# The disease you are curating is: acute bronchitis
# Choose the most appropriate ontology below, if none suitable enter n
# 1.MONDO:0003781 bronchitis
# 2.MONDO:0005607 chronic bronchitis
# 3.MONDO:0018597 plastic bronchitis
# 4.PATO:0000389 acute
# 5.MONDO:0000257 acute diarrhea
# Enter the number of the chosen ontology curation: 1
# The disease you are curating is: agranulocytosis
# Choose the most appropriate ontology below, if none suitable enter n
# 1.MONDO:0001609 agranulocytosis
# 2.HP:0012234 Agranulocytosis
# 3.MONDO:0021758 acquired agranulocytosis
# 4.HP:0005541 Congenital agranulocytosis
# Enter the number of the chosen ontology curation: 1
# The disease you are curating is: asthma
# Choose the most appropriate ontology below, if none suitable enter n
# 1.MONDO:0004979 asthma
# 2.HP:0002099 Asthma
# 3.MONDO:0022742 occupational asthma
# 4.MONDO:0004765 intrinsic asthma
# 5.MONDO:0004784 allergic asthma
# Enter the number of the chosen ontology curation: 1
# The disease you are curating is: schizophrenia
# Choose the most appropriate ontology below, if none suitable enter n
# 1.MONDO:0005090 schizophrenia
# 2.MONDO:0012054 schizophrenia 12
# 3.MONDO:0033312 schizophrenia 19
# 4.MONDO:0011960 schizophrenia 11
# 5.MONDO:0013089 schizophrenia 13
# Enter the number of the chosen ontology curation: 1
# The disease you are curating is: multiple sclerosis
# Choose the most appropriate ontology below, if none suitable enter n
# 1.MONDO:0005301 multiple sclerosis
# 2.MONDO:0018784 pediatric multiple sclerosis
# 3.MONDO:0016428 multiple sclerosis variant
# 4.MONDO:0016429 Marburg acute multiple sclerosis
# 5.MONDO:0005314 relapsing-remitting multiple sclerosis
# Enter the number of the chosen ontology curation: 1
# The disease you are curating is: eating disorders
# Choose the most appropriate ontology below, if none suitable enter n
# 1.MONDO:0015645 eating seizures
# 2.MONDO:0005451 eating disorder
# 3.GO:0042755 eating behavior
# 4.MONDO:0043862 voice disorders
# 5.MONDO:0024417 perceptual disorders
# Enter the number of the chosen ontology curation: 2
# The disease you are curating is: fibrosis and cirrhosis of liver
# Choose the most appropriate ontology below, if none suitable enter n
# Enter the number of the chosen ontology curation: n
# If you would like to try to search a different term, enter it now, if not enter ncirrhosis of liver
# Choose the most appropriate ontology below, if none suitable enter n
# 1.MONDO:0005155 cirrhosis of liver
# 2.MONDO:0006644 alcoholic liver cirrhosis
# 3.MONDO:0005448 hepatitis C induced liver cirrhosis
# 4.HP:0001394 Cirrhosis
# 5.MONDO:0007329 cirrhosis, familial
# Enter the number of the chosen ontology curation: 1
# The disease you are curating is: influenza due to certain identified influenza virus
# Choose the most appropriate ontology below, if none suitable enter n
# 1.MONDO:0013855 influenza, severe, susceptibility to
# 2.NCBITaxon:11320 Influenza A virus
# 3.NCBITaxon:12845 Swine influenza virus
# 4.MONDO:0005812 influenza
# 5.MONDO:0001003 pneumoconiosis due to talc
# Enter the number of the chosen ontology curation: 4
# The disease you are curating is: iron deficiency anaemia
# Choose the most appropriate ontology below, if none suitable enter n
# 1.MONDO:0001356 iron deficiency anemia
# 2.CHEBI:35136 iron protein
# 3.CHEBI:18248 iron atom
# 4.MONDO:0800385 iron poisoning
# 5.CHEBI:50816 iron oxide
# Enter the number of the chosen ontology curation: 1
# The disease you are curating is: gastro-oesophageal reflux disease
# Choose the most appropriate ontology below, if none suitable enter n
# 1.MONDO:0007186 gastroesophageal reflux disease
# 2.MONDO:0015617 genetic gastro-esophageal disease
# 3.MONDO:0006735 duodenogastric reflux
# 4.MONDO:0006677 bile reflux
# 5.MONDO:0006007 vesicoureteral reflux
# Enter the number of the chosen ontology curation: 1
# The disease you are curating is: varicose veins of lower extremities
# Choose the most appropriate ontology below, if none suitable enter n
# 1.HP:0002619 Varicose veins
# 2.HP:0009815 Aplasia/hypoplasia of the extremities
# 3.MONDO:0008643 veins, pattern of, on anterior thorax
# 4.MONDO:0018185 congenital anomaly of the great veins
# 5.MONDO:0008638 varicose disease
# Enter the number of the chosen ontology curation: 5
# The disease you are curating is: insulin-dependent diabetes mellitus
# Choose the most appropriate ontology below, if none suitable enter n
# 1.MONDO:0010255 diabetes mellitus, insulin-dependent, X-linked, susceptibility to
# 2.MONDO:0011955 diabetes mellitus, noninsulin-dependent, 4
# 3.MONDO:0011072 diabetes mellitus, noninsulin-dependent, 2
# 4.MONDO:0011027 diabetes mellitus, noninsulin-dependent, 1
# 5.MONDO:0014488 diabetes mellitus, noninsulin-dependent, 5
# Enter the number of the chosen ontology curation: n
# If you would like to try to search a different term, enter it now, if not enter ndiabetes mellitus
# Choose the most appropriate ontology below, if none suitable enter n
# 1.HP:0000819 Diabetes mellitus
# 2.MONDO:0005015 diabetes mellitus
# 3.MONDO:0010773 myopathy and diabetes mellitus
# 4.MONDO:0016391 neonatal diabetes mellitus
# 5.MONDO:0100180 diabetes mellitus, ketosis-prone
# Enter the number of the chosen ontology curation: 2
# The disease you are curating is: dental caries
# Choose the most appropriate ontology below, if none suitable enter n
# 1.MONDO:0005276 dental caries
# 2.MONDO:0005592 smooth surface dental caries
# 3.MONDO:0005591 pit and fissure surface dental caries
# 4.MONDO:0001041 dentin caries
# 5.MONDO:0006957 root caries
# Enter the number of the chosen ontology curation: 1

# %% [markdown]
# Needed to add this manually

# %%
curation_dict['haemorrhoids'] = {'obo_id': 'MONDO:0004872', 'label': 'hemorrhoid'}

# %%
pprint.pprint(curation_dict)
# Out:
# {'acute bronchitis': {'label': 'bronchitis', 'obo_id': 'MONDO:0003781'},
#  'agranulocytosis': {'label': 'agranulocytosis', 'obo_id': 'MONDO:0001609'},
#  'asthma': {'label': 'asthma', 'obo_id': 'MONDO:0004979'},
#  'bipolar affective disorder': {'label': 'manic bipolar affective disorder',
#                                 'obo_id': 'MONDO:0024612'},
#  'cardiomyopathy': {'label': 'cardiomyopathy', 'obo_id': 'MONDO:0004994'},
#  'dental caries': {'label': 'dental caries', 'obo_id': 'MONDO:0005276'},
#  'eating disorders': {'label': 'eating disorder', 'obo_id': 'MONDO:0005451'},
#  'fibrosis and cirrhosis of liver': {'label': 'cirrhosis of liver',
#                                      'obo_id': 'MONDO:0005155'},
#  'gastro-oesophageal reflux disease': {'label': 'gastroesophageal reflux '
#                                                 'disease',
#                                        'obo_id': 'MONDO:0007186'},
#  'haemorrhoids': {'label': 'hemorrhoid', 'obo_id': 'MONDO:0004872'},
#  'influenza due to certain identified influenza virus': {'label': 'influenza',
#                                                          'obo_id': 'MONDO:0005812'},
#  'insulin-dependent diabetes mellitus': {'label': 'diabetes mellitus',
#                                          'obo_id': 'MONDO:0005015'},
#  'iron deficiency anaemia': {'label': 'iron deficiency anemia',
#                              'obo_id': 'MONDO:0001356'},
#  'multiple sclerosis': {'label': 'multiple sclerosis',
#                         'obo_id': 'MONDO:0005301'},
#  'obesity': {'label': 'obesity disorder', 'obo_id': 'MONDO:0011122'},
#  'sarcoidosis': {'label': 'sarcoidosis', 'obo_id': 'MONDO:0019338'},
#  'schizophrenia': {'label': 'schizophrenia', 'obo_id': 'MONDO:0005090'},
#  'thyroiditis': {'label': 'thyroiditis', 'obo_id': 'MONDO:0004126'},
#  'varicose veins of lower extremities': {'label': 'varicose disease',
#                                          'obo_id': 'MONDO:0008638'}}

# %%
label_dict = {k:v['label'] for k,v in curation_dict.items()}

# %% [markdown]
# MONDO doesn't have a single term for fibrosis and cirrhosis of liver, I automatically added the cirrhosis term and will add the fibrosis term in an adhoc way below

# %%
label_dict['fibrosis and cirrhosis of liver'] = 'cirrhosis of liver,fibrotic liver disease'

# %%
curie_dict = {v['label']:v['obo_id'] for v in curation_dict.values()}

# %%
curie_dict['fibrotic liver disease'] = 'MONDO:0100430'

# %%
test_df2 = ind_df.replace(label_dict, regex=True)

# %%
def make_ontology_string(label_string):
    if label_string:
        split_string = label_string.split(',')
        curies = [curie_dict[label] for label in split_string]
        joined_curies = ','.join(curies)
        return(joined_curies)
    else:
        return

# %%
disease_label_series = test_df2['diseases_diseaseCode.label']
curies_list= []
for row in disease_label_series.iterrows():
    if row[1][0]:
        curies_list.append(make_ontology_string(row[1][0]))
    else:
        curies_list.append(None)

# %%
test_df2["diseases_diseaseCode.id"] = curies_list

# %%
test_df2
# Out:
#      ﻿diseases_ageOfOnset                    diseases_diseaseCode.id  \
# 1                    None                                       None
# 2                    None                                       None
# 3                    None                                       None
# 4                    None                                       None
# 5                    None                                       None
# ...                   ...                                        ...
# 2500                 None                MONDO:0001609,MONDO:0004126
# 2501                 None  MONDO:0019338,MONDO:0005155,MONDO:0100430
# 2502                 None                                       None
# 2503                 None                MONDO:0004126,MONDO:0007186
# 2504                 None                MONDO:0005155,MONDO:0100430
#
#                              diseases_diseaseCode.label  \
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# ...                                                 ...
# 2500                        agranulocytosis,thyroiditis
# 2501  sarcoidosis,cirrhosis of liver,fibrotic liver ...
# 2502                                               None
# 2503        thyroiditis,gastroesophageal reflux disease
# 2504          cirrhosis of liver,fibrotic liver disease
#
#      diseases_familyHistory diseases_notes diseases_severity.id  \
# 1                      None           None                 None
# 2                      None           None                 None
# 3                      None           None                 None
# 4                      None           None                 None
# 5                      None           None                 None
# ...                     ...            ...                  ...
# 2500                   None           None                 None
# 2501                   None           None                 None
# 2502                   None           None                 None
# 2503                   None           None                 None
# 2504                   None           None                 None
#
#      diseases_severity.label diseases_stage.id diseases_stage.label  \
# 1                       None              None                 None
# 2                       None              None                 None
# 3                       None              None                 None
# 4                       None              None                 None
# 5                       None              None                 None
# ...                      ...               ...                  ...
# 2500                    None              None                 None
# 2501                    None              None                 None
# 2502                    None              None                 None
# 2503                    None              None                 None
# 2504                    None              None                 None
#
#      ethnicity.id  ... treatments_cumulativeDose.referenceRange.low  \
# 1     NCIT:C42331  ...                                         None
# 2     NCIT:C41261  ...                                         None
# 3     NCIT:C41260  ...                                         None
# 4     NCIT:C67109  ...                                         None
# 5     NCIT:C67109  ...                                         None
# ...           ...  ...                                          ...
# 2500  NCIT:C43856  ...                                         None
# 2501  NCIT:C67109  ...                                         None
# 2502  NCIT:C67109  ...                                         None
# 2503         None  ...                                         None
# 2504  NCIT:C41260  ...                                         None
#
#      treatments_cumulativeDose.referenceRange.unit  \
# 1                                             None
# 2                                             None
# 3                                             None
# 4                                             None
# 5                                             None
# ...                                            ...
# 2500                                          None
# 2501                                          None
# 2502                                          None
# 2503                                          None
# 2504                                          None
#
#      treatments_cumulativeDose.unit.id treatments_cumulativeDose.unit.label  \
# 1                                 None                                 None
# 2                                 None                                 None
# 3                                 None                                 None
# 4                                 None                                 None
# 5                                 None                                 None
# ...                                ...                                  ...
# 2500                              None                                 None
# 2501                              None                                 None
# 2502                              None                                 None
# 2503                              None                                 None
# 2504                              None                                 None
#
#      treatments_cumulativeDose.value treatments_doseIntervals  \
# 1                               None                     None
# 2                               None                     None
# 3                               None                     None
# 4                               None                     None
# 5                               None                     None
# ...                              ...                      ...
# 2500                            None                     None
# 2501                            None                     None
# 2502                            None                     None
# 2503                            None                     None
# 2504                            None                     None
#
#      treatments_routeOfAdministration.id  \
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None
# 5                                   None
# ...                                  ...
# 2500                                None
# 2501                                None
# 2502                                None
# 2503                                None
# 2504                                None
#
#      treatments_routeOfAdministration.label treatments_treatmentCode.id  \
# 1                                      None                        None
# 2                                      None                        None
# 3                                      None                        None
# 4                                      None                        None
# 5                                      None                        None
# ...                                     ...                         ...
# 2500                                   None                        None
# 2501                                   None                        None
# 2502                                   None                        None
# 2503                                   None                        None
# 2504                                   None                        None
#
#      treatments_treatmentCode.label
# 1                              None
# 2                              None
# 3                              None
# 4                              None
# 5                              None
# ...                             ...
# 2500                           None
# 2501                           None
# 2502                           None
# 2503                           None
# 2504                           None
#
# [2504 rows x 82 columns]

# %% [markdown]
# ## Fix ethnicity labels to match ontology curies
#
# currently the labels do not match the curated codes.

# %%
ethnicities = test_df2['ethnicity.label'].values.tolist()
ethnicities_label_list = [item for sublist in ethnicities for item in sublist]
non_none_ethnicities = list(filter(lambda item: item is not None, ethnicities_label_list))
distinct_ethnicities = set(non_none_ethnicities)

# %%
distinct_ethnicities
# Out:
# {'African',
#  'Any other Asian background',
#  'Any other Black background',
#  'Any other mixed background',
#  'Any other white background',
#  'Asian or Asian British',
#  'Bangladeshi',
#  'Black or Black British',
#  'British',
#  'Caribbean',
#  'Chinese',
#  'Indian',
#  'Irish',
#  'Mixed',
#  'Other ethnic group',
#  'Pakistani',
#  'White',
#  'White and Asian',
#  'White and Black African',
#  'White and Black Caribbean'}

# %%
ethnicities = test_df2['ethnicity.id'].values.tolist()
ethnicities_label_list = [item for sublist in ethnicities for item in sublist]
non_none_ethnicities = list(filter(lambda item: item is not None, ethnicities_label_list))
distinct_ethnicities_curies = set(non_none_ethnicities)

# %%
distinct_ethnicities_curies
# Out:
# {'NCIT:C16352',
#  'NCIT:C41260',
#  'NCIT:C41261',
#  'NCIT:C42331',
#  'NCIT:C43856',
#  'NCIT:C67109',
#  'NCIT:C77810'}

# %%
ethnic_dict = {}
for ethnic in distinct_ethnicities_curies:
    iri = f"http://purl.obolibrary.org/obo/{ethnic.replace(':', '_')}"
    base_url = f"http://www.ebi.ac.uk/ols/api/ontologies/ncit/terms?iri={iri}"
    headers = CaseInsensitiveDict()
    headers['Accept'] = "application/json"
    response = rq.get(base_url, headers=headers)
    content = json.loads(response.content)
    ethnic_dict[ethnic] = content['_embedded']['terms'][0]['label']

# %%
ethnic_dict
# Out:
# {'NCIT:C43856': 'Irish',
#  'NCIT:C67109': 'Multiracial',
#  'NCIT:C16352': 'Black or African American',
#  'NCIT:C41260': 'Asian',
#  'NCIT:C42331': 'African',
#  'NCIT:C77810': 'Caribbean Indian',
#  'NCIT:C41261': 'White'}

# %%
correct_labels = []
for row in test_df2['ethnicity.id'].iterrows():
    if row[1][0]:
        correct_labels.append(ethnic_dict[row[1][0]])
    else:
        correct_labels.append(None)

# %%
test_df2['ethnicity.label'] = correct_labels

# %%
test_df2['ethnicity.label']
# Out:
#      ethnicity.label
# 1            African
# 2              White
# 3              Asian
# 4        Multiracial
# 5        Multiracial
# ...              ...
# 2500           Irish
# 2501     Multiracial
# 2502     Multiracial
# 2503            None
# 2504           Asian
#
# [2504 rows x 1 columns]

# %%
test_df2.to_csv("individuals_updated_ontologies.csv", index=False)
